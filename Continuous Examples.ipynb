# %%
import pandas as pd
import seaborn as sb
#dont forget to upload the CSV file first
x = pd.read_csv("continuous example.csv",sep="|")

# %%
sb.violinplot(y = "Regional Office", x = "Yield",data = x)
